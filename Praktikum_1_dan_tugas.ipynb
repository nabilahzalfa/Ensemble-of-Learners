# %% [markdown]
# # PRAKTIKUM 1

# %% [markdown]
# ## Import Libraray

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # import DT
from sklearn.ensemble import RandomForestClassifier # import RandomForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ## Persiapan Data

# %%
df = pd.read_csv('data/wbc.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Cek kolom null
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Seleksi fitur

# Slice dataframe mulai dari kolom 'radius_mean' sampai 'fractal_dimension_worst'
X = df.iloc[:,2:-1]
y = df['diagnosis']
y = y.map({'M':1, 'B':0}) # Encode label

# Cek jumlah fitur dan instance
X.shape
# Out:
# (569, 30)

# %% [markdown]
# ## Split data training dan testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Traning Decision Tree

# %%
# Secara default, DecisionTreeClassifier dari scikit-learn akan menggunakan nilai "Gini" untuk kriteria
# Terdapat beberapa "hyperparamater" yang dapat digunakan. Silahka baca dokumentasi
# Pada kasus ini kita akan menggunakan parameter default
dt = DecisionTreeClassifier()

# Sesuaikan dt ke set training
dt.fit(X_train, y_train)

# Memprediksi label set test
y_pred_dt = dt.predict(X_test)

#  menghitung set accuracy
acc_dt = accuracy_score(y_test, y_pred_dt)
print("Test set accuracy: {:.2f}".format(acc_dt))
print(f"Test set accuracy: {acc_dt}")
# Out:
# Test set accuracy: 0.94
# Test set accuracy: 0.9385964912280702

# %% [markdown]
# ## Training RandomForest

# %%
# Pada kasus kali ini kita akan menggunakan estimator pada RandomForest
# Untuk detail parameter (hyperparameter) silahkan cek dokumentasi

rf = RandomForestClassifier(n_estimators=10, random_state=1)

# Sesuaikan dt ke set training
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

#  menghitung set accuracy
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Test set accuracy: {:.2f}".format(acc_rf))
print(f"Test set accuracy: {acc_rf}")
# Out:
# Test set accuracy: 0.96
# Test set accuracy: 0.956140350877193

# %% [markdown]
# # TUGAS PRAKTIKUM 1

# %% [markdown]
# ## Persiapan Data

# %%
df = pd.read_csv('data/mushrooms.csv')
df = df.reset_index()
df.head()
# Out:
#    index class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      0     p         x           s         n       t    p               f
# 1      1     e         x           s         y       t    a               f
# 2      2     e         b           s         w       t    l               f
# 3      3     p         x           y         w       t    p               f
# 4      4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size  ... stalk-surface-below-ring stalk-color-above-ring  \
# 0            c         n  ...                        s                      w
# 1            c         b  ...                        s                      w
# 2            c         b  ...                        s                      w
# 3            c         n  ...                        s                      w
# 4            w         b  ...                        s                      w
#
# ...

# %%
# Data untuk label 
new_labels = {
    'a':0.1,'b':0.2,'c':0.3,'d':0.4,'e':0.5,'f':0.6,'g':0.7,'h':0.8,'i':0.9,'j':1.0,'k':1.1,'l':1.2,'m':1.3,
    'n':1.4,'o':1.5,'p':1.6,'q':1.7,'r':1.8,'s':1.9,'t':2.0,'u':2.1,'v':2.2,'w':2.3,'x':2.4,'y':2.5,'z':2.6
    }

# Encode label
df['cap-shape'] = df['cap-shape'].map(new_labels)
df['cap-surface'] = df['cap-surface'].map(new_labels)
df['cap-color'] = df['cap-color'].map(new_labels)
df['bruises'] = df['bruises'].map(new_labels)
df['odor'] = df['odor'].map(new_labels)
df['gill-attachment'] = df['gill-attachment'].map(new_labels)
df['gill-spacing'] = df['gill-spacing'].map(new_labels)
df['gill-size'] = df['gill-size'].map(new_labels)
df['gill-color'] = df['gill-color'].map(new_labels)
df['stalk-shape'] = df['stalk-shape'].map(new_labels)
df['stalk-root'] = df['stalk-root'].map(new_labels)
df['stalk-surface-above-ring'] = df['stalk-surface-above-ring'].map(new_labels)
df['stalk-surface-below-ring'] = df['stalk-surface-below-ring'].map(new_labels)
df['stalk-color-above-ring'] = df['stalk-color-above-ring'].map(new_labels)
df['stalk-color-below-ring'] = df['stalk-color-below-ring'].map(new_labels)
df['veil-type'] = df['veil-type'].map(new_labels)
df['veil-color'] = df['veil-color'].map(new_labels)
df['ring-number'] = df['ring-number'].map(new_labels)
df['ring-type'] = df['ring-type'].map(new_labels)
df['spore-print-color'] = df['spore-print-color'].map(new_labels)
df['population'] = df['population'].map(new_labels)
df['habitat'] = df['habitat'].map(new_labels)

# Cek data
df.head()
# Out:
#    index class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0      0     p        2.4          1.9        1.4      2.0   1.6
# 1      1     e        2.4          1.9        2.5      2.0   0.1
# 2      2     e        0.2          1.9        2.3      2.0   1.2
# 3      3     p        2.4          2.5        2.3      2.0   1.6
# 4      4     e        2.4          1.9        0.7      0.6   1.4
#
#    gill-attachment  gill-spacing  gill-size  ...  stalk-surface-below-ring  \
# 0              0.6           0.3        1.4  ...                       1.9
# 1              0.6           0.3        0.2  ...                       1.9
# 2              0.6           0.3        0.2  ...                       1.9
# 3              0.6           0.3        1.4  ...                       1.9
# 4              0.6           2.3        0.2  ...                       1.9
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
# Cek kolom null
df.isnull().sum()
# Out:
# index                          0
# class                          0
# cap-shape                      0
# cap-surface                    0
# cap-color                      0
# bruises                        0
# odor                           0
# gill-attachment                0
# gill-spacing                   0
# gill-size                      0
# gill-color                     0
# stalk-shape                    0
# stalk-root                  2480
# stalk-surface-above-ring       0
# stalk-surface-below-ring       0
# stalk-color-above-ring         0
# stalk-color-below-ring         0
# veil-type                      0
# veil-color                     0
# ring-number                    0
# ring-type                      0
# spore-print-color              0
# population                     0
# habitat                        0
# dtype: int64

# %%
# Seleksi fitur

# Slice dataframe mulai dari kolom 'cap-shape' sampai 'habitat'
X = df.iloc[:,2:-1]
y = df['class']
y = y.map({'p':1, 'e':0}) # Encode label

# Cek jumlah fitur dan instance
X.shape
# Out:
# (8124, 21)

# %% [markdown]
# ## Split data training dan testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Menggantikan nilai tak terhingga dengan nilai hingga yang tinggi dan nilai nan dengan angka
X_train = np.nan_to_num(X_train)
y_train = np.nan_to_num(y_train)
X_test = np.nan_to_num(X_test)
y_test = np.nan_to_num(y_test)

# %% [markdown]
# ## Traning Decision Tree

# %%
# Secara default, DecisionTreeClassifier dari scikit-learn akan menggunakan nilai "Gini" untuk kriteria
# Terdapat beberapa "hyperparamater" yang dapat digunakan. Silahka baca dokumentasi
# Pada kasus ini kita akan menggunakan parameter default
dt = DecisionTreeClassifier()

# Sesuaikan dt ke set training
dt.fit((X_train), y_train)

# Memprediksi label set test
y_pred_dt = dt.predict(X_test)

#  menghitung set accuracy
acc_dt = accuracy_score(y_test, y_pred_dt)
print("Test set accuracy: {:.2f}".format(acc_dt))
print(f"Test set accuracy: {acc_dt}")
# Out:
# Test set accuracy: 1.00
# Test set accuracy: 1.0

# %% [markdown]
# ## Training RandomForest

# %%
# Pada kasus kali ini kita akan menggunakan estimator pada RandomForest
# Untuk detail parameter (hyperparameter) silahkan cek dokumentasi

rf = RandomForestClassifier(n_estimators=10, random_state=1)

# Sesuaikan dt ke set training
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

#  menghitung set accuracy
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Test set accuracy: {:.2f}".format(acc_rf))
print(f"Test set accuracy: {acc_rf}")
# Out:
# Test set accuracy: 1.00
# Test set accuracy: 1.0
